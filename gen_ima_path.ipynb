# %%
from PIL import Image
import glob
import os

# %%
files = glob.glob("Malariae\pm-20201224\*.jpg")
# print(files)

# %%
count = 1
for file in files:
    name = file.split("\\")[2]
#     print(name)
    fname = "https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/" + name
    print(fname)
#     count = count + 1
# Out:
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000059.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000060.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000061.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000062.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000063.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000064.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000090.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000091.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Malariae/pm-20201224/0000000092.jpg
# ...
